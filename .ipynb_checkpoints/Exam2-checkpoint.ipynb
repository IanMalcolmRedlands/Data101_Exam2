# %% [markdown]
# # Exam 2
# Author: Ian Malcolm
#
# Special Thanks:

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.defaule = 'colab'

from itables import show

# This stops a few warning messages from showing
pd.options.mode.chained_assignment = None 
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### Load Data

# %%
# Load the data.
file_name = 'flights'
file_location = 'https://joannabieri.com/introdatascience/data/'+file_name+'.csv'
DF = pd.read_csv(file_location)
DF
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0                  819       11.0      UA    1545  N14228    EWR  IAH
# 1                  830       20.0      UA    1714  N24211    LGA  IAH
# 2                  850       33.0      AA    1141  N619AA    JFK  MIA
# 3                 1022      -18.0      B6     725  N804JB    JFK  BQN
# 4                  837      -25.0      DL     461  N668DN    LGA  ATL
# ...                ...        ...     ...     ...     ...    ...  ...
# 336771            1634        NaN      9E    3393     NaN    JFK  DCA
# 336772            2312        NaN      9E    3525     NaN    LGA  SYR
# 336773            1330        NaN      MQ    3461  N535MQ    LGA  BNA
# 336774            1344        NaN      MQ    3572  N511MQ    LGA  CLE
# 336775            1020        NaN      MQ    3531  N839MQ    LGA  RDU
#
#         air_time  distance  hour  minute            time_hour
# 0          227.0    1400.0   5.0    15.0  2013-01-01 10:00:00
# 1          227.0    1416.0   5.0    29.0  2013-01-01 10:00:00
# 2          160.0    1089.0   5.0    40.0  2013-01-01 10:00:00
# 3          183.0    1576.0   5.0    45.0  2013-01-01 10:00:00
# 4          116.0     762.0   6.0     0.0  2013-01-01 11:00:00
# ...          ...       ...   ...     ...                  ...
# 336771       NaN     213.0  14.0    55.0  2013-09-30 18:00:00
# 336772       NaN     198.0  22.0     0.0  2013-10-01 02:00:00
# 336773       NaN     764.0  12.0    10.0  2013-09-30 16:00:00
# 336774       NaN     419.0  11.0    59.0  2013-09-30 15:00:00
# 336775       NaN     431.0   8.0    40.0  2013-09-30 12:00:00
#
# [336776 rows x 19 columns]

# %%
# Load extra data
file_name = 'airports'
file_location = 'https://joannabieri.com/introdatascience/data/'+file_name+'.csv'
ports_df = pd.read_csv(file_location)

file_name = 'airlines'
file_location = 'https://joannabieri.com/introdatascience/data/'+file_name
lines_df = pd.read_csv(file_location)

file_name = 'planes'
file_location = 'https://joannabieri.com/introdatascience/data/'+file_name
planes_df = pd.read_csv(file_location)

# %% [markdown]
# ## Questions

# %% [markdown]
# ### Preliminary

# %%
show(DF)
# Out:
# <table id="itables_dfa7d7f7_cfb3_467d_80cb_2f2cac81d145" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>year</th>
#       <th>month</th>
#       <th>day</th>
#       <th>dep_time</th>
#       <th>sched_dep_time</th>
#       <th>dep_delay</th>
#       <th>arr_time</th>
#       <th>sched_arr_time</th>
#       <th>arr_delay</th>
#       <th>carrier</th>
#       <th>flight</th>
#       <th>tailnum</th>
#       <th>origin</th>
#       <th>dest</th>
#       <th>air_time</th>
#       <th>distance</th>
#       <th>hour</th>
#       <th>minute</th>
#       <th>time_hour</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.js';
#
#     document.querySelectorAll("#itables_dfa7d7f7_cfb3_467d_80cb_2f2cac81d145:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [[2013, 1, 1, 517.0, 515, 2.0, 830.0, 819, 11.0, "UA", 1545, "N14228", "EWR", "IAH", 227.0, 1400.0, 5.0, 15.0, "2013-01-01 10:00:00"], [2013, 1, 1, 533.0, 529, 4.0, 850.0, 830, 20.0, "UA", 1714, "N24211", "LGA", "IAH", 227.0, 1416.0, 5.0, 29.0, "2013-01-01 10:00:00"], [2013, 1, 1, 542.0, 540, 2.0, 923.0, 850, 33.0, "AA", 1141, "N619AA", "JFK", "MIA", 160.0, 1089.0, 5.0, 40.0, "2013-01-01 10:00:00"], [2013, 1, 1, 544.0, 545, -1.0, 1004.0, 1022, -18.0, "B6", 725, "N804JB", "JFK", "BQN", 183.0, 1576.0, 5.0, 45.0, "2013-01-01 10:00:00"], [2013, 1, 1, 554.0, 600, -6.0, 812.0, 837, -25.0, "DL", 461, "N668DN", "LGA", "ATL", 116.0, 762.0, 6.0, 0.0, "2013-01-01 11:00:00"], [2013, 1, 1, 554.0, 558, -4.0, 740.0, 728, 12.0, "UA", 1696, "N39463", "EWR", "ORD", 150.0, 719.0, 5.0, 58.0, "2013-01-01 10:00:00"], [2013, 1, 1, 555.0, 600, -5.0, 913.0, 854, 19.0, "B6", 507, "N516JB", "EWR", "FLL", 158.0, 1065.0, 6.0, 0.0, "2013-01-01 11:00:00"], [2013, 1, 1, 557.0, 600, -3.0, 709.0, 723, -14.0, "EV", 5708, "N829AS", "LGA", "IAD", 53.0, 229.0, 6.0, 0.0, "2013-01-01 11:00:00"], [2013, 1, 1,
# air_time          float64
# distance          float64
# hour              float64
# minute            float64
# time_hour          object
# dtype: object

# %% [markdown]
# Most of the variables are integers or floats, which should make the data easier to work with. From what I can tell the float fields seem to be essentially integers themselves, just with the option for NaN values. That is, except for distance, hour, and minute which seem like they should be pure integers due to not having NaN values.
#
# Only carrier, flight, tailnum, origin, and dest are categorical variables. Maybe the time_hour field is also categorical, but I think that's a bit ambiguous as it can be treated as a timestamp.

# %% [markdown]
# ### Question 1
# What are the ten most common destinations for flights from NYC airports in 2013?

# %%
dest_counts = DF['dest'].value_counts()
dest_counts = pd.DataFrame(dest_counts)
dest_counts = pd.merge(ports_df[['name', 'faa']], dest_counts, right_on='dest', left_on='faa', how='right')
show(dest_counts)

top10dests = dest_counts.head(10)['name']
for dest in top10dests:
    print(dest, end=', ')
# Out:
# <table id="itables_e7afa553_d4b5_4f43_9379_64e8987f69dd" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>name</th>
#       <th>faa</th>
#       <th>count</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.js';
#
#     document.querySelectorAll("#itables_e7afa553_d4b5_4f43_9379_64e8987f69dd:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["Chicago Ohare Intl", "ORD", 17283], ["Hartsfield Jackson Atlanta Intl", "ATL", 17215], ["Los Angeles Intl", "LAX", 16174], ["General Edward Lawrence Logan Intl", "BOS", 15508], ["Orlando Intl", "MCO", 14082], ["Charlotte Douglas Intl", "CLT", 14064], ["San Francisco Intl", "SFO", 13331], ["Fort Lauderdale Hollywood Intl", "FLL", 12055], ["Miami Intl", "MIA", 11728], ["Ronald Reagan Washington Natl", "DCA", 9705], ["Detroit Metro Wayne Co", "DTW", 9384], ["Dallas Fort Worth Intl", "DFW", 8738], ["Raleigh Durham Intl", "RDU", 8163], ["Tampa Intl", "TPA", 7466], ["Denver Intl", "DEN", 7266], ["George Bush Intercontinental", "IAH", 7198], ["Minneapolis St Paul Intl", "MSP", 7185], ["Palm Beach Intl", "PBI", 6554], ["Nashville Intl", "BNA", 6333], ["Mc Carran Intl", "LAS", 5997], ["NaN", "NaN", 5819], ["Washington Dulles Intl", "IAD", 5700], ["Buffalo Niagara Intl", "BUF", 4681], ["Phoenix Sky Harbor Intl", "PHX", 4656], ["Cleveland Hopkins Intl", "CLE", 4573], ["Lambert St Louis Intl", "STL", 4339], ["Chicago Midway Intl", "MDW", 4113], ["Cincinnati Northern Kentucky Intl", "CVG", 3941], ["Seattle Tacoma Intl", "SEA", 3923], ["Louis Armstrong New Orleans Intl", "MSY", 3799], ["Southwest Florida Intl", "RSW", 3537], ["Port Columbus Intl", "CMH", 3524], ["Charleston Afb Intl", "CHS", 2884], ["Pittsburgh Intl", "PIT", 2875], ["General Mitchell Intl", "MKE", 2802], ["San Diego Intl", "SAN", 2737], ["Jacksonville Intl", "JAX", 2720], ["Burlington Intl", "BTV", 2589], ["Salt Lake City Intl", "SLC", 2467], ["Richmond Intl", "RIC", 2454], ["Austin Bergstrom Intl", "AUS", 2439], ["Greater Rochester Intl", "ROC", 2416], ["Portland Intl Jetport", "PWM", 2352], ["William P Hobby", "HOU", 2115], ["Indianapolis Intl", "IND", 2077], ["Kansas City Intl", "MCI", 2008], ["Memphis Intl", "MEM", 1789], ["Baltimore Washington Intl", "BWI", 1781], ["Syracuse Hancock Intl", "SYR", 1761], ["Philadelphia Intl", "PHL", 1632], ["Piedmont Triad", "GSO", 1606], ["Norfolk Intl", "ORF", 1536], ["James M Cox Dayton Intl", "DAY", 1525], ["Portland Intl", "PDX", 1354], ["Sarasota Bradenton Intl", "SRQ", 1211], ["Louisville International Airport", "SDF", 1157], ["NW Arkansas Regional", "XNA", 1036], ["Manchester Regional Airport", "MHT", 1009], ["NaN", "NaN", 896], ["Akron Canton Regional Airport", "CAK", 864], ["Greenville-Spartanburg International", "GSP", 849], ["Eppley Afld", "OMA", 849], ["John Wayne Arpt Orange Co", "SNA", 825], ["Savannah Hilton Head Intl", "SAV", 804], ["Gerald R Ford Intl", "GRR", 765], ["Honolulu Intl", "HNL", 707], ["San Antonio Intl", "SAT", 686], ["Long Beach", "LGB", 668], ["Mc Ghee Tyson", "TYS", 631], ["Dane Co Rgnl Truax Fld", "MSN", 572], ["Des Moines Intl", "DSM", 569], ["NaN", "NaN", 522], ["Bradley Intl", "BDL", 443], ["Albany Intl", "ALB", 439], ["Theodore Francis Green State", "PVD", 376], ["Bangor Intl", "BGR", 375], ["Bob Hope", "BUR", 371], ["NaN", "NaN", 365], ["Will Rogers World", "OKC", 346], ["Norman Y Mineta San Jose Intl", "SJC", 329], ["Tulsa Intl", "TUL", 315], ["Metropolitan Oakland Intl", "OAK", 312], ["Birmingham Intl", "BHM", 297], ["Sacramento Intl", "SMF", 284], ["Asheville Regional Airport", "AVL", 275], ["Nantucket Mem", "ACK", 265], ["Albuquerque International Sunport", "ABQ", 254], ["Martha\\\\'s Vineyard", "MVY", 221], ["Eagle Co Rgnl", "EGE", 213], ["Yeager", "CRW", 138], ["Columbia Metropolitan", "CAE", 116], ["Wilmington Intl", "ILM", 110], ["Cherry Capital Airport", "TVC", 101], ["Myrtle Beach Intl", "MYR", 59], ["Charlottesville-Albemarle", "CHO", 52], ["Gallatin Field", "BZN", 36], ["Jackson Hole Airport", "JAC", 25], ["Palm Springs Intl", "PSP", 19], ["Key West Intl", "EYW", 17], ["Yampa Valley", "HDN", 15], ["Montrose Regional Airport", "MTJ", 15], ["South Bend Rgnl", "SBN", 10], ["Ted Stevens Anchorage Intl", "ANC", 8], ["Blue Grass", "LEX", 1], ["La Guardia", "LGA", 1]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": []};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>
# Chicago Ohare Intl, Hartsfield Jackson Atlanta Intl, Los Angeles Intl, General Edward Lawrence Logan Intl, Orlando Intl, Charlotte Douglas Intl, San Francisco Intl, Fort Lauderdale Hollywood Intl, Miami Intl, Ronald Reagan Washington Natl,

# %% [markdown]
# The ten most common destinations for flights from NYC airports in 2013 were, in descending order, Chicago Ohare Intl, Hartsfield Jackson Atlanta Intl, Los Angeles Intl, General Edward Lawrence Logan Intl, Orlando Intl, Charlotte Douglas Intl, San Francisco Intl, Fort Lauderdale Hollywood Intl, Miami Intl, and Ronald Reagan Washington Natl.

# %% [markdown]
# ### Question 2
# Which airlines have the most flights departing from NYC airports in 2013?

# %%
origin_counts = DF['carrier'].value_counts()
origin_counts = pd.DataFrame(origin_counts)
origin_counts = pd.merge(lines_df[['name','carrier']], origin_counts, how='right',
                         on='carrier')

show(origin_counts)
# Out:
# <table id="itables_8a8b7def_ad1d_48f2_990b_15cb754a7619" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>name</th>
#       <th>carrier</th>
#       <th>count</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.js';
#
#     document.querySelectorAll("#itables_8a8b7def_ad1d_48f2_990b_15cb754a7619:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["United Air Lines Inc.", "UA", 58665], ["JetBlue Airways", "B6", 54635], ["ExpressJet Airlines Inc.", "EV", 54173], ["Delta Air Lines Inc.", "DL", 48110], ["American Airlines Inc.", "AA", 32729], ["Envoy Air", "MQ", 26397], ["US Airways Inc.", "US", 20536], ["Endeavor Air Inc.", "9E", 18460], ["Southwest Airlines Co.", "WN", 12275], ["Virgin America", "VX", 5162], ["AirTran Airways Corporation", "FL", 3260], ["Alaska Airlines Inc.", "AS", 714], ["Frontier Airlines Inc.", "F9", 685], ["Mesa Airlines Inc.", "YV", 601], ["Hawaiian Airlines Inc.", "HA", 342], ["SkyWest Airlines Inc.", "OO", 32]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": []};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>

# %% [markdown]
# The airlines with the most flights out of NYC in 2013 were United Airlines, JebBLue, and ExpressJet (in descending order).

# %% [markdown]
# ### Question 3
# Consider only flights that have non-missing arrival delay information and answer the questions below. Your answer should include the name of the carrier in addition to the carrier code and the values asked.
#
# a. Which carrier had the highest mean arrival delay?
#
# b. Which carrier had the lowest mean arrival delay?

# %%
arr_delays_df = DF[['arr_delay', 'carrier']][~DF['arr_delay'].isna()]

arr_delays_gb = arr_delays_df.groupby(by='carrier')
arr_delays_mean = arr_delays_gb['arr_delay'].mean()

arr_delays_mean = pd.DataFrame(arr_delays_mean)
arr_delays_mean = arr_delays_mean.rename(columns={'arr_delay': 'mean_arr_delay'})
arr_delays_mean = pd.merge(lines_df[['name','carrier']], arr_delays_mean, on='carrier', how='right')
arr_delays_mean = arr_delays_mean.sort_values(by='mean_arr_delay', ascending=False)
arr_delays_mean = arr_delays_mean.reset_index()

show(arr_delays_mean)
print(arr_delays_mean.head(1), arr_delays_mean.tail(1), sep='\n')
# Out:
# <table id="itables_ac158205_0b79_4381_8a70_8b2a7369d17f" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>index</th>
#       <th>name</th>
#       <th>carrier</th>
#       <th>mean_arr_delay</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.js';
#
#     document.querySelectorAll("#itables_ac158205_0b79_4381_8a70_8b2a7369d17f:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [[6, "Frontier Airlines Inc.", "F9", 21.920705], [7, "AirTran Airways Corporation", "FL", 20.115906], [5, "ExpressJet Airlines Inc.", "EV", 15.796431], [15, "Mesa Airlines Inc.", "YV", 15.556985], [10, "SkyWest Airlines Inc.", "OO", 11.931034], [9, "Envoy Air", "MQ", 10.774733], [14, "Southwest Airlines Co.", "WN", 9.64912], [3, "JetBlue Airways", "B6", 9.457973], [0, "Endeavor Air Inc.", "9E", 7.379669], [11, "United Air Lines Inc.", "UA", 3.558011], [12, "US Airways Inc.", "US", 2.129595], [13, "Virgin America", "VX", 1.764464], [4, "Delta Air Lines Inc.", "DL", 1.644341], [1, "American Airlines Inc.", "AA", 0.364291], [8, "Hawaiian Airlines Inc.", "HA", -6.915205], [2, "Alaska Airlines Inc.", "AS", -9.930889]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": []};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>
#    index                    name carrier  mean_arr_delay
# 0      6  Frontier Airlines Inc.      F9       21.920705
#     index                  name carrier  mean_arr_delay
# 15      2  Alaska Airlines Inc.      AS       -9.930889

# %% [markdown]
# a. The carrier with the longest mean arrival delay was Frontier.
#
# b. The carrier with the shortest mean arrival delay was Alaska Airlines.

# %% [markdown]
# ### Question 4
# Consider breaking the day into four time intervals: 12:00am-6am, 6:01am-12pm, 12:01pm-6pm, 6:01pm-11:59pm, then answer the questions below.
#
# a. Calculate the proportion of flights that are delayed at departure at each of these time intervals.
#
# b. Comment on how the likelihood of being delayed change throughout the day? What is the probability of being delayed given each time period?

# %%
dep_delays_df = DF[['dep_delay', 'sched_dep_time']][~DF['dep_delay'].isna()]

dep_delays_df['delayed'] = (dep_delays_df['dep_delay'] > 0)

dep_delays_df['sched_int'] = pd.cut(dep_delays_df['sched_dep_time'],
                                    bins=[0,600,1200,1800,2400],
                                    labels=['00:00-06:00','06:01-12:00','12:01-18:00','18:00-23:59'],
                                    right=True)

dep_delays_gb = dep_delays_df.groupby(by='sched_int')

dep_delays_stats = pd.DataFrame({'total': dep_delays_gb['delayed'].count(),
                                 'delayed': dep_delays_gb['delayed'].sum()})

dep_delays_stats['proportion'] = dep_delays_stats['delayed']/dep_delays_stats['total']

show(dep_delays_stats)
# Out:
# <table id="itables_c18afcd3_6e66_42e1_a3ce_60e7bf14ac81" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>total</th>
#       <th>delayed</th>
#       <th>proportion</th>
#     </tr>
#     <tr>
#       <th>sched_int</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.js';
#
#     document.querySelectorAll("#itables_c18afcd3_6e66_42e1_a3ce_60e7bf14ac81:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["00:00-06:00", 8796, 1819, 0.206799], ["06:01-12:00", 124679, 32466, 0.260397], ["12:01-18:00", 126098, 58325, 0.462537], ["18:00-23:59", 68948, 35822, 0.519551]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "order": []};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>

# %% [markdown]
# a. Between 12am and 6am, about 21% of flights get delayed. About 26% of flights get delayed between 6am and 12pm, about 46% of flights get delayed between 12pm and 6pm, and about 52% of flights get delayed between 6pm and 12am.
#
# b. The likelihood of departure delays goes up during over the course of the day. This is likely a result of flights getting backed up as the day passes. Because the high for total flights occurs in the middle of the day, the airlines have a chance to catch up in the evening, even as they hit their highest rate of delays during that time.

# %% [markdown]
# ### Question 5
# Find the flight with the longest air time.
#
# a. How long is this flight?
#
# b. What city did it fly to?
#
# c. How many seats does the plane that flew this flight have?

# %%
#get flight data
max_id = DF['air_time'].idxmax()
longest_flight = DF.loc[max_id, ['flight', 'air_time','origin', 'dest', 'tailnum']]
longest_flight = longest_flight.to_frame()
longest_flight = longest_flight.transpose()
longest_flight = longest_flight.reset_index().drop(columns='index')

#add city destination
longest_flight = pd.merge(longest_flight, ports_df[['faa', 'name']], how='left',
         left_on='dest', right_on='faa').drop(columns='faa')

#add seats info
longest_flight = pd.merge(longest_flight, planes_df[['tailnum', 'seats']],
                          how='left', on='tailnum')


show(longest_flight)
# Out:
# <table id="itables_ecf85606_6d84_49dd_905d_36bfa6492e73" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>flight</th>
#       <th>air_time</th>
#       <th>origin</th>
#       <th>dest</th>
#       <th>tailnum</th>
#       <th>name</th>
#       <th>seats</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.js';
#
#     document.querySelectorAll("#itables_ecf85606_6d84_49dd_905d_36bfa6492e73:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["15", " 695.0", "EWR", "HNL", "N77066", "Honolulu Intl", 292]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "order": []};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>

# %% [markdown]
# The flight with the longest airtime was flight 15.
#
# a. The flight lasted 11 hours and 15 minutes.
#
# b. The flight landed in Honolulu.
#
# c. The flight used an airplane with 292 total seats.

# %% [markdown]
# ### Question 6
# The airports data frame contains information on a large number of primarily American airports. These data include location information for these airports in the form of latitude and longitude coordinates. In this question we limit our focus to the Contiguous United States. Visualize and describe the distribution of the longitudes of airports in the Contiguous United States. What does this tell you about the geographical distribution of these airports?

# %%
latlam = lambda x: x <= 49.38 and x >= 24.40
lonlam = lambda x: x <= -66.89 and x >= -124.85
.681897], [67.106389, -157.8575], [35.0402222, -106.6091944], [45.4491, -98.4218], [31.5355, -84.1945], [32.0665, -84.1133], [41.253053, -70.060181], [31.611289, -97.230519], [40.978111, -124.108611], [39.457583, -74.577167], [51.878, -176.646], [34.300833, -97.008889], [57.749967, -152.493856], [32.9685594, -96.8364478], [38.810806, -76.867028], [66.5519, -152.6222], [31.3274, -92.549833], [56.961389, -133.910278], [32.987778, -97.318889], [40.3544, -79.9302], [57.503611, -134.585], [33.369944, -81.9645], [33.9486, -83.3263], [42.053333, -102.803889], [33.6493889, -81.6850278], [70.638056, -159.994722], [38.096035, -92.5494875], [52.220278, -174.206389], [41.0375, -81.466917], [60.902778, -161.230556], [56.938611, -154.1825], [58.676778, -156.649278], [68.1336, -151.743], [42.748267, -73.801692], [27.740889, -98.026944], [32.8399, -105.991], [42.5571, -92.4003], [37.435, -105.866667], [46.0949, -118.288], [38.806346, -77.0621], [56.899444, -154.247778], [35.219369, -101.705931], [33.588167, -85.858111], [61.174361, -149.996361], [34.494583, -82.709389], [61.5816, -159.543], [55.042436, -131.572233], [38.942778, -76.568333], [41.6396983, -85.0834933], [62.6467, -160.191], [40.707478, -84.0270781], [40.296372, -78.320022], [57.471389, -153.815278], [39.570129, -104.849294], [38.2131944, -122.2806944], [26.152619, -81.775294], [39.466219, -76.168808], [45.0781, -83.5603], [55.554658, -133.101693], [30.037758, -91.883896], [42.132274, -83.444418], [68.1147, -145.579], [43.991922, -76.021739], [45.927778, -89.730833], [39.2232, -106.869], [42.78175, -71.5147778], [46.157972, -123.878694], [70.4673, -157.436], [33.636719, -

# %% [markdown]
# The map shows that most US airport are located in the eastern half of the contiguous US.

# %% [markdown]
# ### Question 7
# Recreate the plot included below using the flights data. Do the best you can to get as close as possible to what you see here. Once you have created the visualization, in no more than one paragraph, describe what you think the point of this visualization might be.

# %%
#get desired flights
arrival_col = DF['arr_delay'].apply(lambda x: 'ontime' if x <= 0 else 'delayed')
flight_arr_df = DF[['origin', 'dest', 'arr_delay', 'month']]

flight_arr_df['arrival'] = arrival_col
flight_arr_df = flight_arr_df[flight_arr_df['dest'].isin(['PHL','RDU'])]

flight_arr_df = flight_arr_df[flight_arr_df['month'] == 12]

#plot
fig = px.box(flight_arr_df, x='arrival', y='arr_delay', facet_col='origin', facet_row='dest',
            color='dest', color_discrete_sequence=px.colors.qualitative.Pastel,
            category_orders={'origin': ['EWR', 'LGA', 'JFK'],
                             'dest': ['PHL','RDU']},
            template='ggplot2',
            labels={'arr_delay': 'Departure Delay'},
            height=500, width=800
            )

fig.update_layout(legend_title_text='Destination',
                  title_text='Ontime Performance of NYC Flights - Month of December')

fig.for_each_annotation(lambda x: x.update(text=x.text.split('=')[1]))

fig.show()

# %% [markdown]
# Delayed flights tend to be more delayed than arrival flights are early. Also, flights out of JFK airport seem to have a greater range for arrival delay than the other airports in NYC.

# %% [markdown]
# ### Question 8
# Create your own data visualization that explores delayed flights. Here you are using any or all of the data sets to explore a question related to delayed flights. You are encouraged to come up with your own questions, but here are some ideas:
#
# - Is there an association between weather and flight delays?
# - Are large flights or small flights more likely to be late?
# - Are there certain destinations each month that are most likely to be late?
# - Can you find a pattern behind why some carriers are often delayed?
